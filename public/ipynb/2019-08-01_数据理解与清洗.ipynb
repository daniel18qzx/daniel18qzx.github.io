# %% [markdown]
# ---
# title: 数据理解与清洗
# date: 2019-08-01
# categories: [人工智能, 数据挖掘]
# mathjax: false
# ---

# %% [markdown]
# ## 数据集载入

# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

df = pd.read_csv(u"2019-08-01_金融数据描述_data1.csv",encoding = 'gbk')

# %%
df.head()
# Out:
#    Unnamed: 0   custid                          trade_no bank_card_no  \
# 0           5  2791858  20180507115231274000000023057383          卡号1
# 1          10   534047  20180507121002192000000023073000          卡号1
# 2          12  2849787  20180507125159718000000023114911          卡号1
# 3          13  1809708  20180507121358683000000388283484          卡号1
# 4          14  2499829  20180507115448545000000388205844          卡号1
#
#    low_volume_percent  middle_volume_percent  \
# 0                0.01                   0.99
# 1                0.02                   0.94
# 2                0.04                   0.96
# 3                0.00                   0.96
# 4                0.01                   0.99
#
#    take_amount_in_later_12_month_highest  trans_amount_increase_rate_lately  \
# 0                                      0                               0.90
# 1                                   2000                               1.28
# 2                                      0                               1.00
# 3                                   2000                               0.13
# 4                                      0                               0.46
#
#    trans_activity_month  trans_activity_day        ...         \
# 0                  0.55               0.313        ...
# 1                  1.00               0.458        ...
# 2                  1.00               0.114        ...
# 3                  0.57               0.777        ...
# 4                  1.00               0.175        ...
#
#    loans_max_limit  loans_avg_limit  consfin_credit_limit  \
# 0           2900.0           1688.0                1200.0
# 1           3500.0           1758.0               15100.0
# 2           1600.0           1250.0                4200.0
# 3           3200.0           1541.0               16300.0
# 4           2300.0           1630.0                8300.0
#
#    consfin_credibility  consfin_org_count_current  consfin_product_count  \
# 0                 75.0                        1.0                    2.0
# 1                 80.0                        5.0                    6.0
# 2                 87.0                        1.0                    1.0
# 3                 80.0                        5.0                    5.0
# 4                 79.0                        2.0                    2.0
#
#    consfin_max_limit  consfin_avg_limit  latest_query_day  loans_latest_day
# 0             1200.0             1200.0              12.0              18.0
# 1            22800.0             9360.0               4.0               2.0
# 2             4200.0             4200.0               2.0               6.0
# 3            30000.0            12180.0               2.0               4.0
# 4             8400.0             8250.0              22.0             120.0
#
# [5 rows x 90 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4754 entries, 0 to 4753
# Data columns (total 90 columns):
# Unnamed: 0                                    4754 non-null int64
# custid                                        4754 non-null int64
# trade_no                                      4754 non-null object
# bank_card_no                                  4754 non-null object
# low_volume_percent                            4752 non-null float64
# middle_volume_percent                         4752 non-null float64
# take_amount_in_later_12_month_highest         4754 non-null int64
# trans_amount_increase_rate_lately             4751 non-null float64
# trans_activity_month                          4752 non-null float64
# trans_activity_day                            4752 non-null float64
# transd_mcc                                    4752 non-null float64
# trans_days_interval_filter                    4746 non-null float64
# trans_days_interval                           4752 non-null float64
# regional_mobility                             4752 non-null float64
# student_feature                               1756 non-null float64
# repayment_capability                          4754 non-null int64
# is_high_user                                  4754 non-null int64
# number_of_trans_from_2011                     4752 non-null float64
# first_transaction_time                        4752 non-null float64
# historical_trans_amount                       4754 non-null int64
# historical_trans_day                          4752 non-null float64
# rank_trad_1_month                             4752 non-null float64
# trans_amount_3_month                          4754 non-null int64
# avg_consume_less_12_valid_month               4752 non-null float64
# abs                                           4754 non-null int64
# top_trans_count_last_1_month                  4752 non-null float64
# avg_price_last_12_month                       4754 non-null int64
# avg_price_top_last_12_valid_month             4650 non-null float64
# reg_preference_for_trad                       4752 non-null object
# trans_top_time_last_1_month                   4746 non-null float64
# trans_top_time_last_6_month                   4746 non-null float64
# consume_top_time_last_1_month                 4746 non-null float64
# consume_top_time_last_6_month                 4746 non-null float64
# cross_consume_count_last_1_month              4328 non-null float64
# trans_fail_top_count_enum_last_1_month        4738 non-null float64
# trans_fail_top_count_enum_last_6_month        4738 non-null float64
# trans_fail_top_count_enum_last_12_month       4738 non-null float64
# consume_mini_time_last_1_month                4728 non-null float64
# max_cumulative_consume_later_1_month          4754 non-null int64
# max_consume_count_later_6_month               4746 non-null float64
# railway_consume_count_last_12_month           4742 non-null float64
# pawns_auctions_trusts_consume_last_1_month    4754 non-null int64
# pawns_auctions_trusts_consume_last_6_month    4754 non-null int64
# jewelry_consume_count_last_6_month            4742 non-null float64
# status                                        4754 non-null int64
# source                                        4754 non-null object
# first_transaction_day                         4752 non-null float64
# trans_day_last_12_month                       4752 non-null float64
# id_name                                       4478 non-null object
# apply_score                                   4450 non-null float64
# apply_credibility                             4450 non-null float64
# query_org_count                               4450 non-null float64
# query_finance_count                           4450 non-null float64
# query_cash_count                              4450 non-null float64
# query_sum_count                               4450 non-null float64
# latest_query_time                             4450 non-null object
# latest_one_month_apply                        4450 non-null float64
# latest_three_month_apply                      4450 non-null float64
# latest_six_month_apply                        4450 non-null float64
# loans_score                                   4457 non-null float64
# loans_credibility_behavior                    4457 non-null float64
# loans_count                                   4457 non-null float64
# loans_settle_count                            4457 non-null float64
# loans_overdue_count                           4457 non-null float64
# loans_org_count_behavior                      4457 non-null float64
# consfin_org_count_behavior                    4457 non-null float64
# loans_cash_count                              4457 non-null float64
# latest_one_month_loan                         4457 non-null float64
# latest_three_month_loan                       4457 non-null float64
# latest_six_month_loan                         4457 non-null float64
# history_suc_fee                               4457 non-null float64
# history_fail_fee                              4457 non-null float64
# latest_one_month_suc                          4457 non-null float64
# latest_one_month_fail                         4457 non-null float64
# loans_long_time                               4457 non-null float64
# loans_latest_time                             4457 non-null object
# loans_credit_limit                            4457 non-null float64
# loans_credibility_limit                       4457 non-null float64
# loans_org_count_current                       4457 non-null float64
# loans_product_count                           4457 non-null float64
# loans_max_limit                               4457 non-null float64
# loans_avg_limit                               4457 non-null float64
# consfin_credit_limit                          4457 non-null float64
# consfin_credibility                           4457 non-null float64
# consfin_org_count_current                     4457 non-null float64
# consfin_product_count                         4457 non-null float64
# consfin_max_limit                             4457 non-null float64
# consfin_avg_limit                             4457 non-null float64
# latest_query_day                              4450 non-null float64
# loans_latest_day                              4457 non-null float64
# dtypes: float64(70), int64(13), object(7)
# memory usage: 3.3+ MB

# %%
typedic = {} # 类型字典
for name in df.columns:
    typedic[str(df[name].dtype)] = typedic.get(str(df[name].dtype),[])+[name]

for key,value in typedic.items():
    print("{}格式共有{}个: {}".format(key,len(value),value))
    print("")
# Out:
# int64格式共有13个: ['Unnamed: 0', 'custid', 'take_amount_in_later_12_month_highest', 'repayment_capability', 'is_high_user', 'historical_trans_amount', 'trans_amount_3_month', 'abs', 'avg_price_last_12_month', 'max_cumulative_consume_later_1_month', 'pawns_auctions_trusts_consume_last_1_month', 'pawns_auctions_trusts_consume_last_6_month', 'status']
#
# object格式共有7个: ['trade_no', 'bank_card_no', 'reg_preference_for_trad', 'source', 'id_name', 'latest_query_time', 'loans_latest_time']
#
# float64格式共有70个: ['low_volume_percent', 'middle_volume_percent', 'trans_amount_increase_rate_lately', 'trans_activity_month', 'trans_activity_day', 'transd_mcc', 'trans_days_interval_filter', 'trans_days_interval', 'regional_mobility', 'student_feature', 'number_of_trans_from_2011', 'first_transaction_time', 'historical_trans_day', 'rank_trad_1_month', 'avg_consume_less_12_valid_month', 'top_trans_count_last_1_month', 'avg_price_top_last_12_valid_month', 'trans_top_time_last_1_month', 'trans_top_time_last_6_month', 'consume_top_time_last_1_month', 'consume_top_time_last_6_month', 'cross_consume_count_last_1_month', 'trans_fail_top_count_enum_last_1_month', 'trans_fail_top_count_enum_last_6_month', 'trans_fail_top_count_enum_last_12_month', 'consume_mini_time_last_1_month', 'max_consume_count_later_6_month', 'railway_consume_count_last_12_month', 'jewelry_consume_count_last_6_month', 'first_transaction_day', 'trans_day_last_12_month', 'apply_score', 'apply_credibility', 'query_org_count', 'query_finance_count', 'query_cash_count', 'query_sum_count', 'latest_one_month_apply', 'latest_three_month_apply', 'latest_six_month_apply', 'loans_score', 'loans_credibility_behavior', 'loans_count', 'loans_settle_count', 'loans_overdue_count', 'loans_org_count_behavior', 'consfin_org_count_behavior', 'loans_cash_count', 'latest_one_month_loan', 'latest_three_month_loan', 'latest_six_month_loan', 'history_suc_fee', 'history_fail_fee', 'latest_one_month_suc', 'latest_one_month_fail', 'loans_long_time', 'loans_credit_limit', 'loans_credibility_limit', 'loans_org_count_current', 'loans_product_count', 'loans_max_limit', 'loans_avg_limit', 'consfin_credit_limit', 'consfin_credibility', 'consfin_org_count_current', 'consfin_product_count', 'consfin_max_limit', 'consfin_avg_limit', 'latest_query_day', 'loans_latest_day']

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'custid', 'trade_no', 'bank_card_no',
#        'low_volume_percent', 'middle_volume_percent',
#        'take_amount_in_later_12_month_highest',
#        'trans_amount_increase_rate_lately', 'trans_activity_month',
#        'trans_activity_day', 'transd_mcc', 'trans_days_interval_filter',
#        'trans_days_interval', 'regional_mobility', 'student_feature',
#        'repayment_capability', 'is_high_user', 'number_of_trans_from_2011',
#        'first_transaction_time', 'historical_trans_amount',
#        'historical_trans_day', 'rank_trad_1_month', 'trans_amount_3_month',
#        'avg_consume_less_12_valid_month', 'abs',
#        'top_trans_count_last_1_month', 'avg_price_last_12_month',
#        'avg_price_top_last_12_valid_month', 'reg_preference_for_trad',
#        'trans_top_time_last_1_month', 'trans_top_time_last_6_month',
#        'consume_top_time_last_1_month', 'consume_top_time_last_6_month',
#        'cross_consume_count_last_1_month',
#        'trans_fail_top_count_enum_last_1_month',
#        'trans_fail_top_count_enum_last_6_month',
#        'trans_fail_top_count_enum_last_12_month',
#        'consume_mini_time_last_1_month',
#        'max_cumulative_consume_later_1_month',
#        'max_consume_count_later_6_month',
#        'railway_consume_count_last_12_month',
#        'pawns_auctions_trusts_consume_last_1_month',
#        'pawns_auctions_trusts_consume_last_6_month',
#        'jewelry_consume_count_last_6_month', 'status', 'source',
#        'first_transaction_day', 'trans_day_last_12_month', 'id_name',
#        'apply_score', 'apply_credibility', 'query_org_count',
#        'query_finance_count', 'query_cash_count', 'query_sum_count',
#        'latest_query_time', 'latest_one_month_apply',
#        'latest_three_month_apply', 'latest_six_month_apply', 'loans_score',
#        'loans_credibility_behavior', 'loans_count', 'loans_settle_count',
#        'loans_overdue_count', 'loans_org_count_behavior',
#        'consfin_org_count_behavior', 'loans_cash_count',
#        'latest_one_month_loan', 'latest_three_month_loan',
#        'latest_six_month_loan', 'history_suc_fee', 'history_fail_fee',
#        'latest_one_month_suc', 'latest_one_month_fail', 'loans_long_time',
#        'loans_latest_time', 'loans_credit_limit', 'loans_credibility_limit',
#        'loans_org_count_current', 'loans_product_count', 'loans_max_limit',
#        'loans_avg_limit', 'consfin_credit_limit', 'consfin_credibility',
#        'consfin_org_count_current', 'consfin_product_count',
#        'consfin_max_limit', 'consfin_avg_limit', 'latest_query_day',
#        'loans_latest_day'],
#       dtype='object')

# %% [markdown]
# ## 可视化各特征

# %%
name_list_1 = [
       'low_volume_percent', 'middle_volume_percent',
       'take_amount_in_later_12_month_highest',
       'trans_amount_increase_rate_lately', 'trans_activity_month',
       'trans_activity_day', 'transd_mcc', 'trans_days_interval_filter',
       'trans_days_interval', 'regional_mobility', 'student_feature',
       'repayment_capability', 'is_high_user', 'number_of_trans_from_2011',
       'first_transaction_time'
       ]
name_list_2 = [
       'historical_trans_amount',
       'historical_trans_day', 'rank_trad_1_month', 'trans_amount_3_month',
       'avg_consume_less_12_valid_month', 'abs',
       'top_trans_count_last_1_month', 'avg_price_last_12_month',
       'avg_price_top_last_12_valid_month', 'reg_preference_for_trad',
       'trans_top_time_last_1_month', 'trans_top_time_last_6_month',
       'consume_top_time_last_1_month', 'consume_top_time_last_6_month',
       'cross_consume_count_last_1_month',
       ]
name_list_3 = [
       'trans_fail_top_count_enum_last_1_month',
       'trans_fail_top_count_enum_last_6_month',
       'trans_fail_top_count_enum_last_12_month',
       'consume_mini_time_last_1_month',
       'max_cumulative_consume_later_1_month',
       'max_consume_count_later_6_month',
       'railway_consume_count_last_12_month',
       'pawns_auctions_trusts_consume_last_1_month',
       'pawns_auctions_trusts_consume_last_6_month',
       'jewelry_consume_count_last_6_month', 
       'first_transaction_day', 'trans_day_last_12_month', 'apply_score',
       'apply_credibility', 'query_org_count',
       ]
name_list_4 = [
      'query_finance_count', 'query_cash_count', 'query_sum_count',
       'latest_query_time', 'latest_one_month_apply',
       'latest_three_month_apply', 'latest_six_month_apply', 'loans_score',
       'loans_credibility_behavior', 'loans_count', 'loans_settle_count',
       'loans_overdue_count', 'loans_org_count_behavior',
       'consfin_org_count_behavior', 'loans_cash_count',
       ]
name_list_5 = [
      'latest_one_month_loan', 'latest_three_month_loan',
       'latest_six_month_loan', 'history_suc_fee', 'history_fail_fee',
       'latest_one_month_suc', 'latest_one_month_fail', 'loans_long_time',
       'loans_latest_time', 'loans_credit_limit', 'loans_credibility_limit',
       'loans_org_count_current', 'loans_product_count', 'loans_max_limit',
       'loans_avg_limit',
       ]
name_list_6 = [
      'consfin_credit_limit', 'consfin_credibility',
       'consfin_org_count_current', 'consfin_product_count',
       'consfin_max_limit', 'consfin_avg_limit', 'latest_query_day',
       'loans_latest_day'
       ]

# %%
f, ax = plt.subplots(5, 3, figsize=(20, 20))

for i,name in enumerate(name_list_1):     
    sns.countplot(data=df, x=name, hue='status',  ax=ax[i // 3][i % 3])
    
plt.savefig("../img/2019-08-01_金融数据描述_1.png")
plt.close()

# %% [markdown]
# ![](/img/2019-08-01_金融数据描述_1.png)

# %%
f, ax = plt.subplots(5, 3, figsize=(20, 20))

for i,name in enumerate(name_list_2):     
    sns.countplot(data=df, x=name, hue='status',  ax=ax[i // 3][i % 3])
    
plt.savefig("../img/2019-08-01_金融数据描述_2.png")
plt.close()

# %% [markdown]
# ![](/img/2019-08-01_金融数据描述_2.png)

# %%
f, ax = plt.subplots(5, 3, figsize=(20, 20))

for i,name in enumerate(name_list_3):     
    sns.countplot(data=df, x=name, hue='status',  ax=ax[i // 3][i % 3])
    
plt.savefig("../img/2019-08-01_金融数据描述_3.png")
plt.close()

# %% [markdown]
# ![](/img/2019-08-01_金融数据描述_3.png)

# %%
f, ax = plt.subplots(5, 3, figsize=(20, 20))

for i,name in enumerate(name_list_4):     
    sns.countplot(data=df, x=name, hue='status',  ax=ax[i // 3][i % 3])

plt.savefig("../img/2019-08-01_金融数据描述_4.png")
plt.close()

# %% [markdown]
# ![](/img/2019-08-01_金融数据描述_4.png)

# %%
f, ax = plt.subplots(5, 3, figsize=(20, 20))

for i,name in enumerate(name_list_5):     
    sns.countplot(data=df, x=name, hue='status',  ax=ax[i // 3][i % 3])

plt.savefig("../img/2019-08-01_金融数据描述_5.png")
plt.close()

# %% [markdown]
# ![](/img/2019-08-01_金融数据描述_5.png)

# %%
f, ax = plt.subplots(3, 3, figsize=(20, 20))

for i,name in enumerate(name_list_6):     
    sns.countplot(data=df, x=name, hue='status',  ax=ax[i // 3][i % 3])

plt.savefig("../img/2019-08-01_金融数据描述_6.png")
plt.close()

# %% [markdown]
# ![](/img/2019-08-01_金融数据描述_6.png)

# %% [markdown]
# 从以上分布图可以看出，连续型数据的特征基本上符合正态分布，指数分布或者泊松分布等，但在['rank_trad_1_month','trans_top_time_last_1_month','trans_top_time_last_6_month','consume_top_time_last_1_month','consume_top_time_last_6_month','loans_credit_limit','loans_credibility_limit','loans_max_limit','consfin_credibility']这几个特征上出现数据于最左最右位置会出现骤升。从业务层面考虑，暂时未得出满意结论，待确认特征取数逻辑后再分析。
#   还有，'avg_price_last_12_month','consfin_credit_limit'这两个特征虽然是连续型特征，但由图上看，出现标签分段，考虑继续探索，查看是否存在分段。
#
#   另外几个离散型特征，如'reg_preference_for_trad','regional_mobility'等，在标签status上区别明显，感觉是对模型有用的特征。

# %%
sns.boxplot(y = 'consfin_credit_limit',x = 'status',data = df)

plt.savefig("../img/2019-08-01_金融数据描述_7.png")
plt.close()

# %% [markdown]
# ![](/img/2019-08-01_金融数据描述_7.png)

# %%
sns.boxplot(y = 'avg_price_last_12_month',x = 'status',data = df)

plt.savefig("../img/2019-08-01_金融数据描述_8.png")
plt.close()

# %% [markdown]
# ![](/img/2019-08-01_金融数据描述_8.png)

# %%
sns.boxplot(y = 'rank_trad_1_month',x = 'status',data = df)

plt.savefig("../img/2019-08-01_金融数据描述_9.png")
plt.close()

# %% [markdown]
# ![](/img/2019-08-01_金融数据描述_9.png)

# %% [markdown]
# ## 数据预处理

# %% [markdown]
# ### 为什么需要处理缺失值？
#
# 不同缺失值的处理方式在一定程度上影响了特征提取、建模和模型训练缺失值太多，可以尝试着直接删除，如果不删除，处理不好，可能会引来噪声缺失值较少，少于某一缺失率时，直接删除又会带来信息的损失，此时可以采取适当的填充方式。

# %% [markdown]
# ### 缺失率大于多少时应当抛弃该特征？
#
# 一般为70%,但是还要分析该特征与训练目标的重要程度

# %% [markdown]
# ### 缺失值填充有哪些方法？
#
# #### 插值填充
# - 特殊值
# - 均值、加权均值（缺点：降低数据的方差，即随机性）
# - 中位数
# - 众数（多用在类别变数）
# - ...
#
# #### 插补法
# - 随机插补法：从总体中随机抽取某个样本代替缺失样本
# - 多重插补法：通过变量之间的关系对缺失数据进行预测，利用蒙特卡洛方法生成多个完整的数据集，在对这些数据集进行分析，最后对分析结果进行汇总处理
# - 热平台插补：指在非缺失数据集中找到一个与缺失值所在样本相似的样本（匹配样本），利用其中的观测值对缺失值进行插补
# - 拉格朗日差值法
# - 牛顿插值法
#
# > 列的维度上，如果是连续性，就使用平均值插补，如果是离散性，就使用众数来插补; 行的维度上，引入预测模型，可考虑辅助回归，通过变量间的关系来预测缺失数据
#
#
# #### 丢弃
# 如果行和列的缺失达到一定的比例，建议放弃整行或整列数据
#
# #### 模型法
# 更多时候我们会基于已有的其他字段，将缺失字段作为目标变量进行预测，从而得到最为可能的补全值。如果带有缺失值的列是数值变量，采用回归模型补全；如果是分类变量，则采用分类模型补全
#
# #### 专家补全
# 对于少量且具有重要意义的数据记录，专家补足也是非常重要的一种途径
#
# #### 不处理
# - 当缺失值对模型的影响不大时，直接在包含空值的数据上进行数据挖掘
# - 很多模型对于缺失值有容忍度或灵活的处理方法，因此在预处理阶段可以不做处理
# - 树模型对于缺失值的敏感度较低，大部分时候可以在数据有缺失时使用
# - 涉及到距离度量(distance measurement)时，如计算两个点之间的距离，缺失数据就变得比较重要。因为涉及到“距离”这个概念，那么缺失值处理不当就会导致效果很差，如K近邻算法(KNN)和支持向量机(SVM)
# - 线性模型的代价函数(loss function)往往涉及到距离(distance)的计算，计算预测值和真实值之间的差别，这容易导致对缺失值敏感
# - 神经网络的鲁棒性强，对于缺失数据不是非常敏感，但一般没有那么多数据可供使用。
# - 贝叶斯模型对于缺失数据也比较稳定，数据量很小的时候首推贝叶斯模型。

# %% [markdown]
# ### 时间序列
#
# 依情况处理，主要看单独时间字段或时间字段与某些字段的组合属性对目标分析的作用程度，再采取相应方式来进行特征提取比如：可以将时间字段与其他字段属性进行组合，分析每天、每周、每月或特点星期几等情况下特征数据频率信息，总的来说还是得看分析得目标
#
# 通常看到的情况是，除了考虑时间序列这个单独的特征外，往往是将时间序列和具有时间属性的特征联合起来分析，查看组合特征的对所需要分析的内容的影响

# %% [markdown]
# ### 异常值和离群值
#
# 大多数的参数统计数值如均值、标准差、相关系数等，以及基于这些参数的统计分析均对离群值高度敏感。因此离群值的存在会对数据分析造成极大影响
#
# #### 判断
# - 用分位数搞定，看跟平均值的偏差超过几倍标准差
# - LOF算法
# - describe的时候加一个箱型图
#
# #### 处理
# - 对数转换
# - 缩尾
# - 截尾
# - 插值

# %% [markdown]
# ### 无用特征删除

# %% [markdown]
# 将所有object格式的改为数值格式，其中有部分无用特征则可直接删除
#
# 由上可看出需处理包含：['trade_no', 'bank_card_no', 'reg_preference_for_trad', 'source', 'id_name', 'latest_query_time', 'loans_latest_time']

# %%
df['source'].value_counts(dropna = False)
# Out:
# xs    4754
# Name: source, dtype: int64

# %%
to_drop = ['trade_no', 'bank_card_no', 'student_feature','cross_consume_count_last_1_month', 'id_name', 'source']
df = df.drop(to_drop, axis=1)

# %% [markdown]
# ### 缺失填充

# %%
df['reg_preference_for_trad'].value_counts(dropna = False)
# Out:
# 一线城市    3403
# 三线城市    1064
# 境外       150
# 二线城市     131
# 其他城市       4
# NaN        2
# Name: reg_preference_for_trad, dtype: int64

# %%
df['reg_preference_for_trad'].fillna('其他城市',inplace = True)
df['reg_preference_for_trad'].value_counts(dropna = False)
# Out:
# 一线城市    3403
# 三线城市    1064
# 境外       150
# 二线城市     131
# 其他城市       6
# Name: reg_preference_for_trad, dtype: int64

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# latest_three_month_apply                      304
# query_finance_count                           304
# latest_six_month_apply                        304
# latest_query_time                             304
# query_sum_count                               304
# query_cash_count                              304
# latest_one_month_apply                        304
# query_org_count                               304
# apply_credibility                             304
# apply_score                                   304
# latest_query_day                              304
# latest_three_month_loan                       297
# loans_score                                   297
# loans_credibility_behavior                    297
# loans_count                                   297
# loans_settle_count                            297
# loans_overdue_count                           297
# loans_org_count_behavior                      297
# consfin_org_count_behavior                    297
# loans_cash_count                              297
# latest_one_month_loan                         297
# loans_latest_day                              297
# latest_six_month_loan                         297
# loans_product_count                           297
# history_suc_fee                               297
# consfin_avg_limit                             297
# consfin_product_count                         297
# consfin_org_count_current                     297
# consfin_credibility                           297
# consfin_credit_limit                          297
#                                              ...
# trans_amount_increase_rate_lately               3
# trans_days_interval                             2
# regional_mobility                               2
# number_of_trans_from_2011                       2
# middle_volume_percent                           2
# transd_mcc                                      2
# trans_activity_day                              2
# trans_activity_month                            2
# low_volume_percent                              2
# historical_trans_day                            2
# first_transaction_time                          2
# first_transaction_day                           2
# rank_trad_1_month                               2
# avg_consume_less_12_valid_month                 2
# trans_day_last_12_month                         2
# top_trans_count_last_1_month                    2
# max_cumulative_consume_later_1_month            0
# custid                                          0
# status                                          0
# take_amount_in_later_12_month_highest           0
# pawns_auctions_trusts_consume_last_6_month      0
# pawns_auctions_trusts_consume_last_1_month      0
# reg_preference_for_trad                         0
# historical_trans_amount                         0
# avg_price_last_12_month                         0
# abs                                             0
# repayment_capability                            0
# is_high_user                                    0
# trans_amount_3_month                            0
# Unnamed: 0                                      0
# Length: 84, dtype: int64

# %% [markdown]
# ## 特征间探索

# %%
corr = df[:].corr()
plt.figure(figsize=(15, 10))
sb.heatmap(corr)
plt.savefig("../img/2019-08-01_金融数据描述_10.png")
plt.close()

# %% [markdown]
# ![](/img/2019-08-01_金融数据描述_10.png)

# %%
corr
# Out:
#                                        Unnamed: 0    custid  \
# Unnamed: 0                               1.000000 -0.007628
# custid                                  -0.007628  1.000000
# low_volume_percent                       0.002861  0.031430
# middle_volume_percent                   -0.022844  0.090599
# take_amount_in_later_12_month_highest   -0.019728 -0.030282
# trans_amount_increase_rate_lately        0.014076 -0.001299
# trans_activity_month                    -0.021715 -0.118811
# trans_activity_day                      -0.001027 -0.216062
# transd_mcc                              -0.006975 -0.147485
# trans_days_interval_filter              -0.021338  0.144513
# trans_days_interval                     -0.006297  0.200145
# regional_mobility                        0.011694 -0.134926
# student_feature                          0.014227  0.026639
# repayment_capability                    -0.006726 -0.026254
# is_high_user                            -0.002995 -0.004640
# number_of_trans_from_2011                0.016355 -0.276856
# historical_trans_amount                  0.002346 -0.179652
# historical_trans_day                     0.004245 -0.345875
# rank_trad_1_month                        0.011515  0.116798
# trans_amount_3_month                    -0.003329 -0.069252
# avg_consume_less_12_valid_month         -0.001742 -0.087905
# abs                                     -0.004830 -0.059940
# top_trans_count_last_1_month             0.021195  0.101220
# avg_price_last_12_month                  0.011454 -0.090752
# avg_price_top_last_12_valid_month       -0.018637  0.124158
# trans_top_time_last_1_month             -0.007772 -0.003624
# trans_top_time_last_6_month              0.012229  0.063470
# consume_top_time_last_1_month           -0.012425 -0.013828
# consume_top_time_last_6_month            0.010297  0.071615
# cross_consume_count_last_1_month        -0.019612 -0.015749
# ...                                           ...       ...
# loans_score                             -0.014716 -0.006276
# loans_credibility_behavior              -0.000191 -0.023587
# loans_count                              0.008971 -0.104423
# loans_settle_count                       0.008509 -0.106395
# loans_overdue_count                     -0.002123 -0.047870
# loans_org_count_behavior                 0.002662 -0.107997
# consfin_org_count_behavior               0.012062 -0.129297
# loans_cash_count                        -0.002987 -0.078110
# latest_one_month_loan                   -0.001009 -0.082016
# latest_three_month_loan                  0.009841 -0.102432
# latest_six_month_loan                    0.013859 -0.084090
# history_suc_fee                          0.005751 -0.154554
# history_fail_fee                         0.005633 -0.039117
# latest_one_month_suc                     0.000168 -0.078523
# latest_one_month_fail                    0.013939 -0.041356
# loans_long_time                          0.000992 -0.216323
# loans_credit_limit                      -0.006194 -0.160582
# loans_credibility_limit                 -0.033850 -0.000850
# loans_org_count_current                 -0.002987 -0.078110
# loans_product_count                     -0.001941 -0.072159
# loans_max_limit                          0.012189 -0.236185
# loans_avg_limit                         -0.004457 -0.152017
# consfin_credit_limit                     0.005967 -0.093180
# consfin_credibility                      0.007746 -0.041979
# consfin_org_count_current                0.012062 -0.129297
# consfin_product_count                    0.009583 -0.139197
# consfin_max_limit                        0.004020 -0.115324
# consfin_avg_limit                        0.008860 -0.076767
# latest_query_day                         0.020774  0.099208
# loans_latest_day                         0.026387  0.098628
#
#                                        low_volume_percent  \
# Unnamed: 0                                       0.002861
# custid                                           0.031430
# low_volume_percent                               1.000000
# middle_volume_percent                           -0.151504
# take_amount_in_later_12_month_highest           -0.066047
# trans_amount_increase_rate_lately                0.005331
# trans_activity_month                             0.023895
# trans_activity_day                              -0.093754
# transd_mcc                                      -0.095780
# trans_days_interval_filter                       0.054680
# trans_days_interval                              0.062421
# regional_mobility                               -0.042939
# student_feature                                 -0.007327
# repayment_capability                            -0.041522
# is_high_user                                     0.018546
# number_of_trans_from_2011                       -0.031668
# historical_trans_amount                         -0.117333
# historical_trans_day                            -0.068345
# rank_trad_1_month                                0.102996
# trans_amount_3_month                            -0.063526
# avg_consume_less_12_valid_month                 -0.042251
# abs                                             -0.059972
# top_trans_count_last_1_month                     0.037765
# avg_price_last_12_month                         -0.286213
# avg_price_top_last_12_valid_month                0.509637
# trans_top_time_last_1_month                     -0.023020
# trans_top_time_last_6_month                      0.064055
# consume_top_time_last_1_month                   -0.030325
# consume_top_time_last_6_month                    0.026853
# cross_consume_count_last_1_month                 0.056716
# ...                                                   ...
# loans_score                                     -0.007019
# loans_credibility_behavior                       0.037414
# loans_count                                     -0.103643
# loans_settle_count                              -0.115451
# loans_overdue_count                              0.003258
# loans_org_count_behavior                        -0.113256
# consfin_org_count_behavior                      -0.074851
# loans_cash_count                                -0.115566
# latest_one_month_loan                           -0.034938
# latest_three_month_loan                         -0.041141
# latest_six_month_loan                           -0.080426
# history_suc_fee                                 -0.068576
# history_fail_fee                                 0.009093
# latest_one_month_suc                            -0.025131
# latest_one_month_fail                            0.021126
# loans_long_time                                 -0.074834
# loans_credit_limit                              -0.138446
# loans_credibility_limit                         -0.051545
# loans_org_count_current                         -0.115566
# loans_product_count                             -0.114296
# loans_max_limit                                 -0.140173
# loans_avg_limit                                 -0.128145
# consfin_credit_limit                            -0.083987
# consfin_credibility                             -0.032534
# consfin_org_count_current                       -0.074851
# consfin_product_count                           -0.067226
# consfin_max_limit                               -0.096647
# consfin_avg_limit                               -0.094627
# latest_query_day                                 0.069301
# loans_latest_day                                 0.047500
#
#                                        middle_volume_percent  \
# Unnamed: 0                                         -0.022844
# custid                                              0.090599
# low_volume_percent                                 -0.151504
# middle_volume_percent                               1.000000
# take_amount_in_later_12_month_highest              -0.135050
# trans_amount_increase_rate_lately                   0.001608
# trans_activity_month                               -0.031743
# trans_activity_day                                 -0.055491
# transd_mcc                                         -0.094736
# trans_days_interval_filter                          0.010146
# trans_days_interval                                -0.000383
# regional_mobility                                   0.009671
# student_feature                                     0.018852
# repayment_capability                               -0.178436
# is_high_user                                       -0.029172
# number_of_trans_from_2011                          -0.084995
# historical_trans_amount                            -0.255846
# historical_trans_day                               -0.116128
# rank_trad_1_month                                   0.139914
# trans_amount_3_month                               -0.189438
# avg_consume_less_12_valid_month                    -0.154257
# abs                                                -0.247023
# top_trans_count_last_1_month                        0.059410
# avg_price_last_12_month                            -0.556220
# avg_price_top_last_12_valid_month                   0.369498
# trans_top_time_last_1_month                        -0.015316
# trans_top_time_last_6_month                         0.025356
# consume_top_time_last_1_month                      -0.024816
# consume_top_time_last_6_month                       0.033989
# cross_consume_count_last_1_month                   -0.076003
# ...                                                      ...
# loans_score                                        -0.039519
# loans_credibility_behavior                         -0.031636
# loans_count                                         0.093372
# loans_settle_count                                  0.084747
# loans_overdue_count                                 0.055341
# loans_org_count_behavior                            0.086219
# consfin_org_count_behavior                         -0.007761
# loans_cash_count                                    0.123857
# latest_one_month_loan                              -0.017258
# latest_three_month_loan                            -0.007416
# latest_six_month_loan                               0.080167
# history_suc_fee                                     0.038832
# history_fail_fee                                    0.055486
# latest_one_month_suc                               -0.022327
# latest_one_month_fail                              -0.018844
# loans_long_time                                     0.040822
# loans_credit_limit                                 -0.086706
# loans_credibility_limit                             0.090824
# loans_org_count_current                             0.123857
# loans_product_count                                 0.122741
# loans_max_limit                                    -0.145599
# loans_avg_limit                                    -0.110230
# consfin_credit_limit                               -0.153241
# consfin_credibility                                 0.003266
# consfin_org_count_current                          -0.007761
# consfin_product_count                              -0.014847
# consfin_max_limit                                  -0.169575
# consfin_avg_limit                                  -0.174126
# latest_query_day                                   -0.001628
# loans_latest_day                                   -0.003253
#
#                                        take_amount_in_later_12_month_highest  \
# Unnamed: 0                                                         -0.019728
# custid                                                             -0.030282
# low_volume_percent                                                 -0.066047
# middle_volume_percent                                              -0.135050
# take_amount_in_later_12_month_highest                               1.000000
# trans_amount_increase_rate_lately                                  -0.006699
# trans_activity_month                                                0.060997
# trans_activity_day                                                  0.112582
# transd_mcc                                                          0.181435
# trans_days_interval_filter                                         -0.055318
# trans_days_interval                                                -0.053329
# regional_mobility                                                   0.024089
# student_feature                                                    -0.013524
# repayment_capability                                                0.055174
# is_high_user                                                        0.068763
# number_of_trans_from_2011                                           0.056183
# historical_trans_amount                                             0.102959
# historical_trans_day                                                0.112908
# rank_trad_1_month                                                  -0.089095
# trans_amount_3_month                                                0.074279
# avg_consume_less_12_valid_month                                     0.031360
# abs                                                                 0.081978
# top_trans_count_last_1_month                                       -0.063713
# avg_price_last_12_month                                             0.129908
# avg_price_top_last_12_valid_month                                  -0.123202
# trans_top_time_last_1_month                                         0.028547
# trans_top_time_last_6_month                                        -0.079647
# consume_top_time_last_1_month                                       0.022475
# consume_top_time_last_6_month                                      -0.062038
# cross_consume_count_last_1_month                                    0.042310
# ...                                                                      ...
# loans_score                                                        -0.003928
# loans_credibility_behavior                                         -0.017790
# loans_count                                                         0.034853
# loans_settle_count                                                  0.044691
# loans_overdue_count                                                -0.018406
# loans_org_count_behavior                                            0.020780
# consfin_org_count_behavior                                          0.021387
# loans_cash_count                                                    0.016962
# latest_one_month_loan                                               0.008845
# latest_three_month_loan                                             0.009611
# latest_six_month_loan                                               0.034499
# history_suc_fee                                                     0.036804
# history_fail_fee                                                   -0.019751
# latest_one_month_suc                                                0.022699
# latest_one_month_fail                                              -0.004671
# loans_long_time                                                     0.012660
# loans_credit_limit                                                  0.050185
# loans_credibility_limit                                            -0.025575
# loans_org_count_current                                             0.016962
# loans_product_count                                                 0.018572
# loans_max_limit                                                     0.071798
# loans_avg_limit                                                     0.038880
# consfin_credit_limit                                                0.039328
# consfin_credibility                                                 0.015841
# consfin_org_count_current                                           0.021387
# consfin_product_count                                               0.021337
# consfin_max_limit                                                   0.054433
# consfin_avg_limit                                                   0.040634
# latest_query_day                                                   -0.000570
# loans_latest_day                                                   -0.010231
#
#                                        trans_amount_increase_rate_lately  \
# Unnamed: 0                                                      0.014076
# custid                                                         -0.001299
# low_volume_percent                                              0.005331
# middle_volume_percent                                           0.001608
# take_amount_in_later_12_month_highest                          -0.006699
# trans_amount_increase_rate_lately                               1.000000
# trans_activity_month                                            0.015389
# trans_activity_day                                             -0.003061
# transd_mcc                                                     -0.011644
# trans_days_interval_filter                                      0.013220
# trans_days_interval                                             0.000521
# regional_mobility                                              -0.026960
# student_feature                                                -0.002682
# repayment_capability                                           -0.000572
# is_high_user                                                   -0.002017
# number_of_trans_from_2011                                      -0.013609
# historical_trans_amount                                        -0.002527
# historical_trans_day                                           -0.006987
# rank_trad_1_month                                               0.028153
# trans_amount_3_month                                           -0.003598
# avg_consume_less_12_valid_month                                 0.006201
# abs                                                            -0.003474
# top_trans_count_last_1_month                                    0.029701
# avg_price_last_12_month                                        -0.004808
# avg_price_top_last_12_valid_month                              -0.030556
# trans_top_time_last_1_month                                    -0.021723
# trans_top_time_last_6_month                                     0.032999
# consume_top_time_last_1_month                                  -0.020937
# consume_top_time_last_6_month                                   0.032106
# cross_consume_count_last_1_month                               -0.004524
# ...                                                                  ...
# loans_score                                                     0.010481
# loans_credibility_behavior                                     -0.003788
# loans_count                                                    -0.011057
# loans_settle_count                                             -0.011398
# loans_overdue_count                                            -0.009483
# loans_org_count_behavior                                       -0.012629
# consfin_org_count_behavior                                     -0.019901
# loans_cash_count                                               -0.006482
# latest_one_month_loan                                          -0.010482
# latest_three_month_loan                                        -0.012746
# latest_six_month_loan                                          -0.007440
# history_suc_fee                                                -0.013452
# history_fail_fee                                               -0.006480
# latest_one_month_suc                                           -0.009579
# latest_one_month_fail                                          -0.005436
# loans_long_time                                                -0.002678
# loans_credit_limit                                              0.013118
# loans_credibility_limit                                         0.003868
# loans_org_count_current                                        -0.006482
# loans_product_count                                            -0.007575
# loans_max_limit                                                 0.007119
# loans_avg_limit                                                 0.000119
# consfin_credit_limit                                            0.028868
# consfin_credibility                                             0.006174
# consfin_org_count_current                                      -0.019901
# consfin_product_count                                          -0.019603
# consfin_max_limit                                               0.007123
# consfin_avg_limit                                               0.040865
# latest_query_day                                               -0.001457
# loans_latest_day                                                0.027221
#
#                                        trans_activity_month  \
# Unnamed: 0                                        -0.021715
# custid                                            -0.118811
# low_volume_percent                                 0.023895
# middle_volume_percent                             -0.031743
# take_amount_in_later_12_month_highest              0.060997
# trans_amount_increase_rate_lately                  0.015389
# trans_activity_month                               1.000000
# trans_activity_day                                 0.063373
# transd_mcc                                         0.069272
# trans_days_interval_filter                        -0.091630
# trans_days_interval                               -0.151579
# regional_mobility                                 -0.219911
# student_feature                                    0.004966
# repayment_capability                               0.024737
# is_high_user                                       0.044231
# number_of_trans_from_2011                         -0.198322
# historical_trans_amount                            0.016522
# historical_trans_day                               0.052108
# rank_trad_1_month                                 -0.017110
# trans_amount_3_month                               0.010864
# avg_consume_less_12_valid_month                    0.014532
# abs                                                0.038276
# top_trans_count_last_1_month                      -0.026923
# avg_price_last_12_month                           -0.006858
# avg_price_top_last_12_valid_month                  0.011839
# trans_top_time_last_1_month                        0.018931
# trans_top_time_last_6_month                       -0.016856
# consume_top_time_last_1_month                      0.021517
# consume_top_time_last_6_month                     -0.009154
# cross_consume_count_last_1_month                  -0.001588
# ...                                                     ...
# loans_score                                       -0.020418
# loans_credibility_behavior                         0.002694
# loans_count                                        0.010844
# loans_settle_count                                 0.006203
# loans_overdue_count                                0.026175
# loans_org_count_behavior                           0.014655
# consfin_org_count_behavior                         0.003332
# loans_cash_count                                   0.018475
# latest_one_month_loan                              0.010030
# latest_three_month_loan                            0.024060
# latest_six_month_loan                              0.023376
# history_suc_fee                                    0.008331
# history_fail_fee                                   0.033715
# latest_one_month_suc                               0.009873
# latest_one_month_fail                              0.017951
# loans_long_time                                    0.030914
# loans_credit_limit                                 0.036172
# loans_credibility_limit                           -0.005513
# loans_org_count_current                            0.018475
# loans_product_count                                0.019401
# loans_max_limit                                    0.061847
# loans_avg_limit                                    0.037275
# consfin_credit_limit                              -0.036822
# consfin_credibility                               -0.000400
# consfin_org_count_current                          0.003332
# consfin_product_count                              0.005534
# consfin_max_limit                                 -0.022388
# consfin_avg_limit                                 -0.043764
# latest_query_day                                  -0.024161
# loans_latest_day                                  -0.014880
#
#                                        trans_activity_day  transd_mcc  \
# Unnamed: 0                                      -0.001027   -0.006975
# custid                                          -0.216062   -0.147485
# low_volume_percent                              -0.093754   -0.095780
# middle_volume_percent                           -0.055491   -0.094736
# take_amount_in_later_12_month_highest            0.112582    0.181435
# trans_amount_increase_rate_lately               -0.003061   -0.011644
# trans_activity_month                             0.063373    0.069272
# trans_activity_day                               1.000000    0.674547
# transd_mcc                                       0.674547    1.000000
# trans_days_interval_filter                      -0.491304   -0.407126
# trans_days_interval                             -0.542118   -0.447308
# regional_mobility                                0.143697    0.114936
# student_feature                                  0.011653    0.005921
# repayment_capability                             0.189494    0.115434
# is_high_user                                    -0.034766   -0.080892
# number_of_trans_from_2011                        0.286353    0.262917
# historical_trans_amount                          0.526801    0.392433
# historical_trans_day                             0.855832    0.603820
# rank_trad_1_month                               -0.517923   -0.481565
# trans_amount_3_month                             0.293735    0.250140
# avg_consume_less_12_valid_month                  0.081550    0.194729
# abs                                              0.306292    0.160103
# top_trans_count_last_1_month                    -0.503568   -0.475823
# avg_price_last_12_month                          0.068127    0.067431
# avg_price_top_last_12_valid_month               -0.138470   -0.145411
# trans_top_time_last_1_month                      0.092705    0.143620
# trans_top_time_last_6_month                     -0.519642   -0.400228
# consume_top_time_last_1_month                    0.126348    0.162267
# consume_top_time_last_6_month                   -0.506739   -0.371122
# cross_consume_count_last_1_month                 0.217779    0.236684
# ...                                                   ...         ...
# loans_score                                     -0.211471   -0.141698
# loans_credibility_behavior                      -0.059242   -0.028579
# loans_count                                      0.713700    0.433028
# loans_settle_count                               0.723008    0.440667
# loans_overdue_count                              0.319103    0.193574
# loans_org_count_behavior                         0.698811    0.451913
# consfin_org_count_behavior                       0.553486    0.371197
# loans_cash_count                                 0.662281    0.420938
# latest_one_month_loan                            0.251331    0.152255
# latest_three_month_loan                          0.277217    0.180567
# latest_six_month_loan                            0.618386    0.381795
# history_suc_fee                                  0.707752    0.432147
# history_fail_fee                                 0.269878    0.148111
# latest_one_month_suc                             0.228821    0.146654
# latest_one_month_fail                            0.133230    0.080658
# loans_long_time                                  0.384281    0.301560
# loans_credit_limit                               0.229054    0.177929
# loans_credibility_limit                          0.161363    0.154721
# loans_org_count_current                          0.662281    0.420938
# loans_product_count                              0.656939    0.416980
# loans_max_limit                                  0.445155    0.313715
# loans_avg_limit                                  0.202242    0.165959
# consfin_credit_limit                             0.096622    0.066250
# consfin_credibility                              0.181157    0.131905
# consfin_org_count_current                        0.553486    0.371197
# consfin_product_count                            0.551140    0.374660
# consfin_max_limit                                0.224509    0.156951
# consfin_avg_limit                                0.085255    0.057663
# latest_query_day                                -0.188965   -0.120330
# loans_latest_day                                -0.299110   -0.211593
#
#                                        trans_days_interval_filter  \
# Unnamed: 0                                              -0.021338
# custid                                                   0.144513
# low_volume_percent                                       0.054680
# middle_volume_percent                                    0.010146
# take_amount_in_later_12_month_highest                   -0.055318
# trans_amount_increase_rate_lately                        0.013220
# trans_activity_month                                    -0.091630
# trans_activity_day                                      -0.491304
# transd_mcc                                              -0.407126
# trans_days_interval_filter                               1.000000
# trans_days_interval                                      0.690819
# regional_mobility                                       -0.124350
# student_feature                                         -0.005412
# repayment_capability                                    -0.048998
# is_high_user                                             0.146678
# number_of_trans_from_2011                               -0.181413
# historical_trans_amount                                 -0.254563
# historical_trans_day                                    -0.424616
# rank_trad_1_month                                        0.345540
# trans_amount_3_month                                    -0.139654
# avg_consume_less_12_valid_month                         -0.017535
# abs                                                     -0.054408
# top_trans_count_last_1_month                             0.381422
# avg_price_last_12_month                                 -0.003254
# avg_price_top_last_12_valid_month                        0.064464
# trans_top_time_last_1_month                             -0.127328
# trans_top_time_last_6_month                              0.541678
# consume_top_time_last_1_month                           -0.155562
# consume_top_time_last_6_month                            0.489491
# cross_consume_count_last_1_month                        -0.098826
# ...                                                           ...
# loans_score                                              0.105373
# loans_credibility_behavior                               0.016791
# loans_count                                             -0.340780
# loans_settle_count                                      -0.346732
# loans_overdue_count                                     -0.145065
# loans_org_count_behavior                                -0.330187
# consfin_org_count_behavior                              -0.287044
# loans_cash_count                                        -0.298750
# latest_one_month_loan                                   -0.109048
# latest_three_month_loan                                 -0.132316
# latest_six_month_loan                                   -0.294128
# history_suc_fee                                         -0.361614
# history_fail_fee                                        -0.115664
# latest_one_month_suc                                    -0.111359
# latest_one_month_fail                                   -0.053043
# loans_long_time                                         -0.317888
# loans_credit_limit                                      -0.146462
# loans_credibility_limit                                 -0.083218
# loans_org_count_current                                 -0.298750
# loans_product_count                                     -0.295409
# loans_max_limit                                         -0.222970
# loans_avg_limit                                         -0.118522
# consfin_credit_limit                                    -0.055205
# consfin_credibility                                     -0.142221
# consfin_org_count_current                               -0.287044
# consfin_product_count                                   -0.286212
# consfin_max_limit                                       -0.111345
# consfin_avg_limit                                       -0.045801
# latest_query_day                                         0.069560
# loans_latest_day                                         0.163433
#
#                                              ...         loans_max_limit  \
# Unnamed: 0                                   ...                0.012189
# custid                                       ...               -0.236185
# low_volume_percent                           ...               -0.140173
# middle_volume_percent                        ...               -0.145599
# take_amount_in_later_12_month_highest        ...                0.071798
# trans_amount_increase_rate_lately            ...                0.007119
# trans_activity_month                         ...                0.061847
# trans_activity_day                           ...                0.445155
# transd_mcc                                   ...                0.313715
# trans_days_interval_filter                   ...               -0.222970
# trans_days_interval                          ...               -0.271875
# regional_mobility                            ...                0.099696
# student_feature                              ...                0.021982
# repayment_capability                         ...                0.128100
# is_high_user                                 ...               -0.006073
# number_of_trans_from_2011                    ...                0.195444
# historical_trans_amount                      ...                0.324514
# historical_trans_day                         ...                0.430792
# rank_trad_1_month                            ...               -0.235028
# trans_amount_3_month                         ...                0.186909
# avg_consume_less_12_valid_month              ...                0.054239
# abs                                          ...                0.152274
# top_trans_count_last_1_month                 ...               -0.199205
# avg_price_last_12_month                      ...                0.204154
# avg_price_top_last_12_valid_month            ...               -0.316923
# trans_top_time_last_1_month                  ...                0.039372
# trans_top_time_last_6_month                  ...               -0.227717
# consume_top_time_last_1_month                ...                0.053634
# consume_top_time_last_6_month                ...               -0.228478
# cross_consume_count_last_1_month             ...                0.101269
# ...                                          ...                     ...
# loans_score                                  ...               -0.145502
# loans_credibility_behavior                   ...               -0.109592
# loans_count                                  ...                0.454809
# loans_settle_count                           ...                0.466131
# loans_overdue_count                          ...                0.189896
# loans_org_count_behavior                     ...                0.462677
# consfin_org_count_behavior                   ...                0.357549
# loans_cash_count                             ...                0.443326
# latest_one_month_loan                        ...                0.216387
# latest_three_month_loan                      ...                0.235019
# latest_six_month_loan                        ...                0.395462
# history_suc_fee                              ...                0.439947
# history_fail_fee                             ...                0.164983
# latest_one_month_suc                         ...                0.194397
# latest_one_month_fail                        ...                0.104707
# loans_long_time                              ...                0.368329
# loans_credit_limit                           ...                0.745694
# loans_credibility_limit                      ...                0.328845
# loans_org_count_current                      ...                0.443326
# loans_product_count                          ...                0.441316
# loans_max_limit                              ...                1.000000
# loans_avg_limit                              ...                0.716175
# consfin_credit_limit                         ...                0.108760
# consfin_credibility                          ...                0.101659
# consfin_org_count_current                    ...                0.357549
# consfin_product_count                        ...                0.354231
# consfin_max_limit                            ...                0.208389
# consfin_avg_limit                            ...                0.109425
# latest_query_day                             ...               -0.190074
# loans_latest_day                             ...               -0.282204
#
#                                        loans_avg_limit  consfin_credit_limit  \
# Unnamed: 0                                   -0.004457              0.005967
# custid                                       -0.152017             -0.093180
# low_volume_percent                           -0.128145             -0.083987
# middle_volume_percent                        -0.110230             -0.153241
# take_amount_in_later_12_month_highest         0.038880              0.039328
# trans_amount_increase_rate_lately             0.000119              0.028868
# trans_activity_month                          0.037275             -0.036822
# trans_activity_day                            0.202242              0.096622
# transd_mcc                                    0.165959              0.066250
# trans_days_interval_filter                   -0.118522             -0.055205
# trans_days_interval                          -0.163049             -0.034716
# regional_mobility                             0.062712              0.092796
# student_feature                               0.007634              0.001860
# repayment_capability                          0.066266              0.052900
# is_high_user                                  0.014809              0.001286
# number_of_trans_from_2011                     0.142227              0.105527
# historical_trans_amount                       0.165218              0.137554
# historical_trans_day                          0.223623              0.111262
# rank_trad_1_month                            -0.121879             -0.120020
# trans_amount_3_month                          0.084463              0.065007
# avg_consume_less_12_valid_month               0.010832              0.024610
# abs                                           0.105389              0.072716
# top_trans_count_last_1_month                 -0.082819             -0.071977
# avg_price_last_12_month                       0.186553              0.183277
# avg_price_top_last_12_valid_month            -0.285338             -0.172475
# trans_top_time_last_1_month                   0.019334              0.005990
# trans_top_time_last_6_month                  -0.111353             -0.055343
# consume_top_time_last_1_month                 0.023311              0.018442
# consume_top_time_last_6_month                -0.109085             -0.055605
# cross_consume_count_last_1_month              0.038369              0.032169
# ...                                                ...                   ...
# loans_score                                  -0.071344              0.076157
# loans_credibility_behavior                   -0.059538              0.113228
# loans_count                                   0.167113              0.097746
# loans_settle_count                            0.175771              0.109141
# loans_overdue_count                           0.071337              0.001805
# loans_org_count_behavior                      0.133557              0.065915
# consfin_org_count_behavior                    0.137506              0.102057
# loans_cash_count                              0.108990              0.034866
# latest_one_month_loan                         0.078718              0.057899
# latest_three_month_loan                       0.083134              0.055062
# latest_six_month_loan                         0.110447              0.067585
# history_suc_fee                               0.158091              0.129951
# history_fail_fee                              0.047106              0.008807
# latest_one_month_suc                          0.056937              0.023565
# latest_one_month_fail                         0.041028             -0.000725
# loans_long_time                               0.268476              0.144168
# loans_credit_limit                            0.901755              0.085200
# loans_credibility_limit                       0.456704             -0.022646
# loans_org_count_current                       0.108990              0.034866
# loans_product_count                           0.108962              0.031936
# loans_max_limit                               0.716175              0.108760
# loans_avg_limit                               1.000000              0.091117
# consfin_credit_limit                          0.091117              1.000000
# consfin_credibility                           0.031452              0.241837
# consfin_org_count_current                     0.137506              0.102057
# consfin_product_count                         0.137271              0.081338
# consfin_max_limit                             0.130307              0.788637
# consfin_avg_limit                             0.098641              0.901470
# latest_query_day                             -0.099086             -0.047756
# loans_latest_day                             -0.144835             -0.110230
#
#                                        consfin_credibility  \
# Unnamed: 0                                        0.007746
# custid                                           -0.041979
# low_volume_percent                               -0.032534
# middle_volume_percent                             0.003266
# take_amount_in_later_12_month_highest             0.015841
# trans_amount_increase_rate_lately                 0.006174
# trans_activity_month                             -0.000400
# trans_activity_day                                0.181157
# transd_mcc                                        0.131905
# trans_days_interval_filter                       -0.142221
# trans_days_interval                              -0.102588
# regional_mobility                                 0.054084
# student_feature                                   0.009800
# repayment_capability                              0.007068
# is_high_user                                     -0.000752
# number_of_trans_from_2011                         0.066191
# historical_trans_amount                           0.073505
# historical_trans_day                              0.142560
# rank_trad_1_month                                -0.133787
# trans_amount_3_month                              0.033856
# avg_consume_less_12_valid_month                   0.026514
# abs                                               0.009934
# top_trans_count_last_1_month                     -0.138804
# avg_price_last_12_month                          -0.017057
# avg_price_top_last_12_valid_month                -0.002851
# trans_top_time_last_1_month                       0.060674
# trans_top_time_last_6_month                      -0.151634
# consume_top_time_last_1_month                     0.073859
# consume_top_time_last_6_month                    -0.128403
# cross_consume_count_last_1_month                  0.024935
# ...                                                    ...
# loans_score                                      -0.043698
# loans_credibility_behavior                        0.202241
# loans_count                                       0.189068
# loans_settle_count                                0.183622
# loans_overdue_count                               0.089767
# loans_org_count_behavior                          0.231726
# consfin_org_count_behavior                        0.297390
# loans_cash_count                                  0.156549
# latest_one_month_loan                             0.087776
# latest_three_month_loan                           0.099953
# latest_six_month_loan                             0.169560
# history_suc_fee                                   0.194162
# history_fail_fee                                  0.098387
# latest_one_month_suc                              0.092642
# latest_one_month_fail                             0.053177
# loans_long_time                                   0.229963
# loans_credit_limit                                0.057358
# loans_credibility_limit                          -0.029875
# loans_org_count_current                           0.156549
# loans_product_count                               0.155744
# loans_max_limit                                   0.101659
# loans_avg_limit                                   0.031452
# consfin_credit_limit                              0.241837
# consfin_credibility                               1.000000
# consfin_org_count_current                         0.297390
# consfin_product_count                             0.288275
# consfin_max_limit                                 0.216232
# consfin_avg_limit                                 0.275861
# latest_query_day                                 -0.085131
# loans_latest_day                                 -0.230984
#
#                                        consfin_org_count_current  \
# Unnamed: 0                                              0.012062
# custid                                                 -0.129297
# low_volume_percent                                     -0.074851
# middle_volume_percent                                  -0.007761
# take_amount_in_later_12_month_highest                   0.021387
# ...
# trans_top_time_last_6_month                            -0.336984
# consume_top_time_last_1_month                           0.083782
# consume_top_time_last_6_month                          -0.331808
# cross_consume_count_last_1_month                        0.129515
# ...                                                          ...
# loans_score                                            -0.242594
# loans_credibility_behavior                              0.132995
# loans_count                                             0.669975
# loans_settle_count                                      0.633814
# loans_overdue_count                                     0.389047
# loans_org_count_behavior                                0.799828
# consfin_org_count_behavior                              1.000000
# loans_cash_count                                        0.555002
# latest_one_month_loan                                   0.328566
# latest_three_month_loan                                 0.410173
# latest_six_month_loan                                   0.653119
# history_suc_fee                                         0.682134
# history_fail_fee                                        0.399674
# latest_one_month_suc                                    0.349219
# latest_one_month_fail                                   0.228943
# loans_long_time                                         0.345921
# loans_credit_limit                                      0.151520
# loans_credibility_limit                                 0.115503
# loans_org_count_current                                 0.555002
# loans_product_count                                     0.553607
# loans_max_limit                                         0.357549
# loans_avg_limit                                         0.137506
# consfin_credit_limit                                    0.102057
# consfin_credibility                                     0.297390
# consfin_org_count_current                               1.000000
# consfin_product_count                                   0.988027
# consfin_max_limit                                       0.345697
# consfin_avg_limit                                       0.074170
# latest_query_day                                       -0.185038
# loans_latest_day                                       -0.399885
#
#                                        consfin_product_count  \
# Unnamed: 0                                          0.009583
# custid                                             -0.139197
# low_volume_percent                                 -0.067226
# middle_volume_percent                              -0.014847
# take_amount_in_later_12_month_highest               0.021337
# trans_amount_increase_rate_lately                  -0.019603
# trans_activity_month                                0.005534
# trans_activity_day                                  0.551140
# transd_mcc                                          0.374660
# trans_days_interval_filter                         -0.286212
# trans_days_interval                                -0.286510
# regional_mobility                                   0.145322
# student_feature                                     0.017777
# repayment_capability                                0.046471
# is_high_user                                       -0.017732
# number_of_trans_from_2011                           0.215217
# historical_trans_amount                             0.288420
# historical_trans_day                                0.473890
# rank_trad_1_month                                  -0.327323
# trans_amount_3_month                                0.153457
# avg_consume_less_12_valid_month                     0.101638
# abs                                                 0.074592
# top_trans_count_last_1_month                       -0.324179
# avg_price_last_12_month                             0.017570
# avg_price_top_last_12_valid_month                  -0.080339
# trans_top_time_last_1_month                         0.056594
# trans_top_time_last_6_month                        -0.334724
# consume_top_time_last_1_month                       0.080835
# consume_top_time_last_6_month                      -0.329305
# cross_consume_count_last_1_month                    0.131031
# ...                                                      ...
# loans_score                                        -0.249384
# loans_credibility_behavior                          0.141105
# loans_count                                         0.658099
# loans_settle_count                                  0.618343
# loans_overdue_count                                 0.396295
# loans_org_count_behavior                            0.784147
# consfin_org_count_behavior                          0.988027
# loans_cash_count                                    0.539896
# latest_one_month_loan                               0.334659
# latest_three_month_loan                             0.415173
# latest_six_month_loan                               0.646769
# history_suc_fee                                     0.674063
# history_fail_fee                                    0.411005
# latest_one_month_suc                                0.360903
# latest_one_month_fail                               0.244784
# loans_long_time                                     0.337877
# loans_credit_limit                                  0.152471
# loans_credibility_limit                             0.114720
# loans_org_count_current                             0.539896
# loans_product_count                                 0.539424
# loans_max_limit                                     0.354231
# loans_avg_limit                                     0.137271
# consfin_credit_limit                                0.081338
# consfin_credibility                                 0.288275
# consfin_org_count_current                           0.988027
# consfin_product_count                               1.000000
# consfin_max_limit                                   0.329687
# consfin_avg_limit                                   0.054292
# latest_query_day                                   -0.183685
# loans_latest_day                                   -0.402011
#
#                                        consfin_max_limit  consfin_avg_limit  \
# Unnamed: 0                                      0.004020           0.008860
# custid                                         -0.115324          -0.076767
# low_volume_percent                             -0.096647          -0.094627
# middle_volume_percent                          -0.169575          -0.174126
# take_amount_in_later_12_month_highest           0.054433           0.040634
# trans_amount_increase_rate_lately               0.007123           0.040865
# trans_activity_month                           -0.022388          -0.043764
# trans_activity_day                              0.224509           0.085255
# transd_mcc                                      0.156951           0.057663
# trans_days_interval_filter                     -0.111345          -0.045801
# trans_days_interval                            -0.105000          -0.024740
# regional_mobility                               0.091150           0.079245
# student_feature                                 0.000096           0.004799
# repayment_capability                            0.063720           0.052120
# is_high_user                                    0.007764           0.013155
# number_of_trans_from_2011                       0.138342           0.088776
# historical_trans_amount                         0.201670           0.138920
# historical_trans_day                            0.219427           0.097498
# rank_trad_1_month                              -0.180749          -0.115613
# trans_amount_3_month                            0.094556           0.063275
# avg_consume_less_12_valid_month                 0.044864           0.011955
# abs                                             0.102727           0.090651
# top_trans_count_last_1_month                   -0.128756          -0.058697
# avg_price_last_12_month                         0.179284           0.205885
# avg_price_top_last_12_valid_month              -0.197348          -0.195194
# trans_top_time_last_1_month                     0.021747           0.000811
# trans_top_time_last_6_month                    -0.106172          -0.042912
# consume_top_time_last_1_month                   0.038965           0.012452
# consume_top_time_last_6_month                  -0.105383          -0.042412
# cross_consume_count_last_1_month                0.041163           0.025667
# ...                                                  ...                ...
# loans_score                                    -0.004854           0.085289
# loans_credibility_behavior                      0.112848           0.110999
# loans_count                                     0.240708           0.067635
# loans_settle_count                              0.239062           0.079620
# loans_overdue_count                             0.109103          -0.020359
# loans_org_count_behavior                        0.257087           0.038651
# consfin_org_count_behavior                      0.345697           0.074170
# loans_cash_count                                0.164961           0.012515
# latest_one_month_loan                           0.136317           0.039233
# latest_three_month_loan                         0.158521           0.038337
# latest_six_month_loan                           0.214958           0.040151
# history_suc_fee                                 0.258122           0.092018
# history_fail_fee                                0.130966          -0.011496
# latest_one_month_suc                            0.119473           0.014118
# latest_one_month_fail                           0.078403          -0.011238
# loans_long_time                                 0.198060           0.134422
# loans_credit_limit                              0.123290           0.087213
# loans_credibility_limit                         0.021164          -0.036374
# loans_org_count_current                         0.164961           0.012515
# loans_product_count                             0.163650           0.009397
# loans_max_limit                                 0.208389           0.109425
# loans_avg_limit                                 0.130307           0.098641
# consfin_credit_limit                            0.788637           0.901470
# consfin_credibility                             0.216232           0.275861
# consfin_org_count_current                       0.345697           0.074170
# consfin_product_count                           0.329687           0.054292
# consfin_max_limit                               1.000000           0.790580
# consfin_avg_limit                               0.790580           1.000000
# latest_query_day                               -0.096890          -0.042131
# loans_latest_day                               -0.193945          -0.088072
#
#                                        latest_query_day  loans_latest_day
# Unnamed: 0                                     0.020774          0.026387
# custid                                         0.099208          0.098628
# low_volume_percent                             0.069301          0.047500
# middle_volume_percent                         -0.001628         -0.003253
# take_amount_in_later_12_month_highest         -0.000570         -0.010231
# trans_amount_increase_rate_lately             -0.001457          0.027221
# trans_activity_month                          -0.024161         -0.014880
# trans_activity_day                            -0.188965         -0.299110
# transd_mcc                                    -0.120330         -0.211593
# trans_days_interval_filter                     0.069560          0.163433
# trans_days_interval                            0.102343          0.178628
# regional_mobility                             -0.051839         -0.107139
# student_feature                               -0.020274         -0.031571
# repayment_capability                          -0.020964         -0.049951
# is_high_user                                  -0.011908         -0.015299
# number_of_trans_from_2011                     -0.087938         -0.140635
# historical_trans_amount                       -0.087267         -0.156048
# historical_trans_day                          -0.171007         -0.267034
# rank_trad_1_month                              0.139572          0.243659
# trans_amount_3_month                          -0.044342         -0.099134
# avg_consume_less_12_valid_month               -0.069481         -0.090181
# abs                                           -0.042772         -0.065586
# top_trans_count_last_1_month                   0.140451          0.247943
# avg_price_last_12_month                       -0.033386         -0.020140
# avg_price_top_last_12_valid_month              0.079399          0.062422
# trans_top_time_last_1_month                   -0.030739         -0.069952
# trans_top_time_last_6_month                    0.088539          0.199473
# consume_top_time_last_1_month                 -0.044495         -0.078152
# consume_top_time_last_6_month                  0.083349          0.194636
# cross_consume_count_last_1_month              -0.026850         -0.081532
# ...                                                 ...               ...
# loans_score                                    0.035587         -0.019444
# loans_credibility_behavior                     0.014235         -0.034587
# loans_count                                   -0.194495         -0.388366
# loans_settle_count                            -0.198341         -0.374859
# loans_overdue_count                           -0.069116         -0.166293
# loans_org_count_behavior                      -0.216354         -0.402870
# consfin_org_count_behavior                    -0.185038         -0.399885
# loans_cash_count                              -0.197164         -0.337008
# latest_one_month_loan                         -0.167327         -0.564125
# latest_three_month_loan                       -0.172112         -0.556912
# latest_six_month_loan                         -0.201667         -0.457269
# history_suc_fee                               -0.197019         -0.392292
# history_fail_fee                              -0.060527         -0.199490
# latest_one_month_suc                          -0.167496         -0.459412
# latest_one_month_fail                         -0.051815         -0.232811
# loans_long_time                               -0.134214         -0.214274
# loans_credit_limit                            -0.111170         -0.157736
# loans_credibility_limit                       -0.127687         -0.138313
# loans_org_count_current                       -0.197164         -0.337008
# loans_product_count                           -0.199549         -0.348389
# loans_max_limit                               -0.190074         -0.282204
# loans_avg_limit                               -0.099086         -0.144835
# consfin_credit_limit                          -0.047756         -0.110230
# consfin_credibility                           -0.085131         -0.230984
# consfin_org_count_current                     -0.185038         -0.399885
# consfin_product_count                         -0.183685         -0.402011
# consfin_max_limit                             -0.096890         -0.193945
# consfin_avg_limit                             -0.042131         -0.088072
# latest_query_day                               1.000000          0.230078
# loans_latest_day                               0.230078          1.000000
#
# [82 rows x 82 columns]

# %% [markdown]
# > 参考：
#
# 1. [DataWhale数据挖掘实战营](https://github.com/datawhalechina/Datawhale_Learning/tree/master/doc/%E7%90%86%E8%AE%BA%E5%BA%94%E7%94%A8/%E6%95%B0%E6%8D%AE%E6%8C%96%E6%8E%98)
# 2. [利用Python进行数据分析·第2版](https://www.jianshu.com/p/29ece4592178)
# 3. [Stata：离群值！离群值？离群值！](https://www.jianshu.com/p/0c967a1526ef)
# 4. [机器学习中如何处理不平衡数据？](https://www.jiqizhixin.com/articles/021704)
