# %% [markdown]
# ---
# title: 链家网房源
# date: 2019-06-29
# id: 1
# categories: [爬虫, 项目]
# ---

# %%
import requests
import time
from bs4 import BeautifulSoup

# %%
#设置列表页URL的固定部分
url='http://bj.lianjia.com/ershoufang/'
#设置页面页的可变部分
page=('pg')

# %%
#设置请求头部信息
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.11 (KHTML, like Gecko) Chrome/23.0.1271.64 Safari/537.11',
'Accept':'text/html;q=0.9,*/*;q=0.8',
'Accept-Charset':'ISO-8859-1,utf-8;q=0.7,*;q=0.3',
'Accept-Encoding':'gzip',
'Connection':'close',
'Referer':'http://www.baidu.com/link?url=_andhfsjjjKRgEWkj7i9cFmYYGsisrnm2A-TN3XZDQXxvGsM9k9ZZSnikW2Yds4s&amp;amp;wd=&amp;amp;eqid=c3435a7d00146bd600000003582bfd1f'
}

# %%
#循环抓取列表页信息
for i in range(1,2):
     if i == 1:
          i=str(i)
          a=(url+page+i+'/')
          r=requests.get(url=a,headers=headers)
          html=r.content
     else:
          i=str(i)
          a=(url+page+i+'/')
          r=requests.get(url=a,headers=headers)
          html2=r.content
          html = html + html2
     #每次间隔1秒
     time.sleep(1)

# %%
#解析抓取的页面内容
lj=BeautifulSoup(html,'html.parser')

# %%
#提取房源总价
price=lj.find_all('div','priceInfo')
tp=[]
for a in price:
    totalPrice=a.span.string
    tp.append(totalPrice)

# %%
#提取房源信息
houseInfo=lj.find_all('div',attrs={'class':'houseInfo'})
 
hi=[]
for b in houseInfo:
    house=b.get_text()
    hi.append(house)

# %%
#提取房源关注度
followInfo=lj.find_all('div',attrs={'class':'followInfo'})
 
fi=[]
for c in followInfo:
    follow=c.get_text()
    fi.append(follow)

# %%
#导入pandas库
import pandas as pd
#创建数据表
house=pd.DataFrame({'totalprice':tp,'houseinfo':hi,'followinfo':fi})
#查看数据表的内容
house.head()
# Out:
#   totalprice                           houseinfo  \
# 0       1390  阳光上东滨河花园 /2室1厅/190.65平米/南 北/简装/有电梯
# 1        230         住欣家园 /1室1厅/49.47平米/南/精装/有电梯
# 2        295        建材城西二里 /1室1厅/46.3平米/东/简装/无电梯
# 3      599.9          晨月园 /1室1厅/68.04平米/南/简装/有电梯
# 4       1030    新外大街甲25号院 /3室2厅/103平米/南 北/简装/有电梯
#
#                                      followinfo
# 0          19人关注/15次带看VR房源房本满五年1390万单价72909元/平米
# 1         62人关注/8次带看近地铁VR房源房本满五年230万单价46493元/平米
# 2         20人关注/4次带看近地铁VR房源房本满五年295万单价63715元/平米
# 3  37人关注/11次带看近地铁VR房源房本满五年随时看房599.9万单价88169元/平米
# 4          26人关注/28次带看近地铁房本满两年1030万单价100000元/平米

# %%
#对房源信息进行分列
houseinfo_split = pd.DataFrame((x.split('/') for x in house.houseinfo),index=house.index,columns=['小区','户型','面积','朝向','装修','电梯'])

# %%
#查看分列结果
houseinfo_split.head()
# Out:
#            小区    户型        面积   朝向  装修   电梯
# 0   阳光上东滨河花园   2室1厅  190.65平米  南 北  简装  有电梯
# 1       住欣家园   1室1厅   49.47平米    南  精装  有电梯
# 2     建材城西二里   1室1厅    46.3平米    东  简装  无电梯
# 3        晨月园   1室1厅   68.04平米    南  简装  有电梯
# 4  新外大街甲25号院   3室2厅     103平米  南 北  简装  有电梯

# %%
#将分列结果拼接回原数据表
house=pd.merge(house,houseinfo_split,right_index=True, left_index=True)
house.head()

# %%
#对房源关注度进行分列
followinfo_split = pd.DataFrame((x.split('/') for x in house.followinfo),index=house.index,columns=['guanzhu','daikan','fabu'])
#将分列后的关注度信息拼接回原数据表
house=pd.merge(house,followinfo_split,right_index=True, left_index=True)
house.head()
# Out:
#   totalprice                           houseinfo  \
# 0       1390  阳光上东滨河花园 /2室1厅/190.65平米/南 北/简装/有电梯
# 1        230         住欣家园 /1室1厅/49.47平米/南/精装/有电梯
# 2        295        建材城西二里 /1室1厅/46.3平米/东/简装/无电梯
# 3      599.9          晨月园 /1室1厅/68.04平米/南/简装/有电梯
# 4       1030    新外大街甲25号院 /3室2厅/103平米/南 北/简装/有电梯
#
#                                      followinfo          小区    户型        面积  \
# 0          19人关注/15次带看VR房源房本满五年1390万单价72909元/平米   阳光上东滨河花园   2室1厅  190.65平米
# 1         62人关注/8次带看近地铁VR房源房本满五年230万单价46493元/平米       住欣家园   1室1厅   49.47平米
# 2         20人关注/4次带看近地铁VR房源房本满五年295万单价63715元/平米     建材城西二里   1室1厅    46.3平米
# 3  37人关注/11次带看近地铁VR房源房本满五年随时看房599.9万单价88169元/平米        晨月园   1室1厅   68.04平米
# 4          26人关注/28次带看近地铁房本满两年1030万单价100000元/平米  新外大街甲25号院   3室2厅     103平米
#
#     朝向  装修   电梯 guanzhu_x                             daikan_x fabu_x  \
# 0  南 北  简装  有电梯     19人关注          15次带看VR房源房本满五年1390万单价72909元     平米
# 1    南  精装  有电梯     62人关注         8次带看近地铁VR房源房本满五年230万单价46493元     平米
# 2    东  简装  无电梯     20人关注         4次带看近地铁VR房源房本满五年295万单价63715元     平米
# 3    南  简装  有电梯     37人关注  11次带看近地铁VR房源房本满五年随时看房599.9万单价88169元     平米
# 4  南 北  简装  有电梯     26人关注          28次带看近地铁房本满两年1030万单价100000元     平米
#
#   guanzhu_y                             daikan_y fabu_y guanzhu  \
# 0     19人关注          15次带看VR房源房本满五年1390万单价72909元     平米   19人关注
# 1     62人关注         8次带看近地铁VR房源房本满五年230万单价46493元     平米   62人关注
# 2     20人关注         4次带看近地铁VR房源房本满五年295万单价63715元     平米   20人关注
# 3     37人关注  11次带看近地铁VR房源房本满五年随时看房599.9万单价88169元     平米   37人关注
# 4     26人关注          28次带看近地铁房本满两年1030万单价100000元     平米   26人关注
#
#                                 daikan fabu
# 0          15次带看VR房源房本满五年1390万单价72909元   平米
# 1         8次带看近地铁VR房源房本满五年230万单价46493元   平米
# 2         4次带看近地铁VR房源房本满五年295万单价63715元   平米
# 3  11次带看近地铁VR房源房本满五年随时看房599.9万单价88169元   平米
# 4          28次带看近地铁房本满两年1030万单价100000元   平米

# %% [markdown]
# > 参考：
#
# 1. [廖雪峰Python数据分析](https://www.julyedu.com/course/getDetail/66/)
